# %%
#!pip install ruamel.yaml
#!pip install --upgrade pip
#!pip install GPUtil

# !python grid_search.py daanet
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# no gpu found!
# use config: default
# I:[helper.py:190]:number of jobs in the queue: 1
# I:[helper.py:192]:will start the job: python app.py train /var/folders/f4/3pxcc4mj27g65g83bp1hdkbw0000gn/T/daanet-9cwyr8_u ...
# W:[helper.py:201]:there is no gpu, running on cpu!
# no gpu found!
# use config: default
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# I:x:1203-103333:[hel:par:121]:loading parameters...
# ...
